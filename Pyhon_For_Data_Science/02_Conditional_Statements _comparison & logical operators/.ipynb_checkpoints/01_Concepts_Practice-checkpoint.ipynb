# %% [markdown]
# # **Chpater 2: if / elif / else, comparison & logical operators**

# %% [markdown]
# ## **Comparison & logical operatore**

# %% [markdown]
# ## **Comparison Operators**
#
# Comparison operators are used to compare two values and return a Boolean result (True or False) based on the condition.

# %%
a = 10
b = 5

print(a == b)   # False (10 is not equal to 5)
print(a != b)   # True  (10 is not equal to 5)
print(a > b)    # True  (10 is greater than 5)
print(a < b)    # False (10 is not less than 5)
print(a >= b)   # True  (10 is greater or equal to 5)
print(a <= b)   # False (10 is not less or equal to 5)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# ## **Logical Operators**
#
#
# Logical operators are used to combine two or more conditions and return a Boolean result (True or False).

# %%
age = 20
has_id = True

# AND operator
print(age >= 18 and has_id)  
# True (both conditions are True)

# OR operator
print(age < 18 or has_id)   
# True (one condition is True)

# NOT operator
print(not(age >= 18))       
# False (it reverses True to False)
# Out:
# True
# True
# False

# %% [markdown]
# ## **Conditinal Statement**
#
# Conditional statements are used to make decisions in a program.
# They allow the program to execute different blocks of code based on whether a condition is True or False.

# %%
# if condtition
age = int(input("enter your age : "))
if(age > 18):
    print("your are adult")
# Out:
# enter your age :  12

# %%
# elif condition
age = int(input("enter your age : "))
if(age > 18):
    print("your are adult")
elif(age >15 and age < 18):
    print("you are teenager ")
# Out:
# enter your age :  23
# your are adult

# %%
# Else condition 
age = int(input("enter your age : "))
if(age >= 18):
    print("your are adult")
elif(age >= 15 and age <18):
    print("your are teenager")
else:
    print("your are minor")
# Out:
# enter your age :  12
# your are minor

# %% [markdown]
# ## **Practice questions**

# %% [markdown]
#  #### Q1. Positive / Negative / Zero
#
# Take a number as input and check whether it is:
#
# Positive,
# Negative,
# Zero

# %%
num = float(input("Enter number here : "))
if num >0 :
    print("Number is positive")
elif num == 0:
    print("Number is zero ")
else:
    print("Number is negative")
# Out:
# Enter number here :  2
# Number is positive

# %% [markdown]
# #### Q2: Even or Odd
#
# Write a Python program that takes an integer as input from the user and checks whether the number is even or odd.

# %%
num = int(input("Enter number here : "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter number here :  2
# Even

# %% [markdown]
# #### Q3: Voting Eligibility
#
# Write a Python program that takes age as input and checks whether a person is eligible to vote.

# %%
age =int(input("Enter you age: "))
if age >= 18:
    print("Eligible for voting")
else:
    print("Not eligible")
# Out:
# Enter you age :  23
# Eligible for voting

# %% [markdown]
# #### Q4: Divisibility Check
#
# Write a Python program that takes a number as input and checks whether it is divisible by 5.

# %%
num = int(input("Enter number here:"))
if num % 5 == 0:
    print("Yes")
else:
    print("No")
# Out:
# Enter number here: 3
# No

# %% [markdown]
# #### Q5: Pass or Fail
#
# Write a Python program that takes marks as input and checks whether a student has passed or failed.

# %%
marks = int(input("Enter marks here: "))
if marks <0 or marks > 100:
    print("Invalid marks")
elif marks >= 40:
    print("Pass")m
else:
    print("Fail")
# Out:
# Enter marks here:  100
# Pass

# %% [markdown]
# #### Q6: Largest of Two Numbers
#
# Write a Python program that takes two numbers as input and prints the larger number.

# %%
num = int(input("Enter number here: "))
num1 = int(input("Enter number here: "))
if num > num1:
    print(num)
elif num1 > num:
    print(num1)
else:
    print("Both are equal")
# Out:
# Enter number here:  12
# Enter number here:  12
# Both are equal

# %% [markdown]
# #### Q7: Teenager Check
#
# Write a Python program that takes age as input and checks whether a person is a teenager.

# %%
age = int(input("Enter your age: "))
if age >= 13 and age <= 19:
    print("Teenager")
else:
    print("Not a teenager")
# Out:
# Enter your age:  13
# Teenager

# %% [markdown]
#  #### Q8: Divisible by 2 and 3
#
# Write a Python program that takes a number as input and checks whether it is divisible by both 2 and 3.

# %%
num = int(input("Enter number here: "))
if num % 2 == 0 and num % 3 ==0:
    print("Yes")
else:
    print("No")
# Out:
# Enter number here:  9
# No

# %% [markdown]
#  #### Q9: Grade System
#
# Write a Python program that takes marks as input and prints the grade.

# %%
marks = int(input("Enter marks: "))

if marks < 0 or marks > 100:
    print("Invalid marks")
elif marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks:  46
# Fail

# %% [markdown]
#  #### Q10: Leap Year Check
#
# Write a Python program to check whether a given year is a leap year.

# %%
year = int(input("Enter year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year:  2012
# Leap Year

# %% [markdown]
# #### Q11: Largest of Three Numbers
#
# Write a Python program that takes three numbers as input and prints the largest number.

# %%
data = input("Enter the three input here : ")
a,b,c = data.split()
a =int(a)
b = int(b)
c = int(c)
# if a >= b and a>= c:
#     print(a)
# elif b >= a and b >= c:
#     print(b)
# else:
#     print(c)
print(max(a,b,c))
# Out:
# Enter the three input here :  112 34 1454
# 1454

# %% [markdown]
# #### Q12: Number Range Category
#
# Write a Python program that takes a number as input and prints:

# %%
num = int(input("enter number here: "))
if num >= 0 and num <= 10:
    print("Small")
elif num >= 11 and num <=50:
    print("Medium")
else:
    print("Large")
# Out:
# enter number here:  45
# Medium

# %%
# Solution 2
num = int(input("enter number here: "))
if 0 <= num <= 10:
    print("Small")
elif 11 <= num <= 50:
    print("Medium")
else:
    print("Large")
# Out:
# enter number here:  44
# Medium

# %% [markdown]
# #### Q13: Simple Login System
#
# Write a Python program that takes username and password as input:

# %%
username = input("Enter username here: ")
password = input("Enter password here: ")
if username == "Vishal" and password == "vishal233":
    print("Login successfull")
else:
    print("Invalid Credentials")
# Out:
# Enter username here:  Vishal
# Enter password here:  vishal233
# Login successfull

# %% [markdown]
# #### Q14: Triangle Validity
#
# Write a Python program that takes three sides as input and checks whether a triangle can be formed.

# %%
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if a > 0 and b > 0 and c > 0:
    if a + b > c and b + c > a and a + c > b:
        print("Valid Triangle")
    else:
        print("Invalid Triangle")
else:
    print("Invalid Triangle")
# Out:
# Enter first side:  34
# Enter second side:  232
# Enter third side:  2345
# Invalid Triangle
